# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

import sys  
sys.path.append("../l2hmc")
sys.path.append("../l2hmc/utils")
from __future__ import division

import tensorflow as tf
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from utils.distributions import random_tilted_gaussian, Gaussian, GMM, RoughWell

import seaborn as sns
sns.set_palette("muted")

# %%
from utils.func_utils import accept, jacobian, autocovariance, get_log_likelihood, \
    get_data, binarize, normal_kl, acl_spectrum, ESS
from utils.distributions import Gaussian, GMM, GaussianFunnel, gen_ring
from utils.layers import Linear, Sequential, Zip, Parallel, ScaleTanh
from utils.dynamics import Dynamics
from utils.sampler import propose
from utils.notebook_utils import get_hmc_samples, plot_gaussian_contours

# %%
# Color definition for plots
c_l2hmc, c_hmc1, c_hmc2, c_hmc3 = 'blue', 'orange', 'green', 'red'
c_true, c_contour = 'purple', '0.75'

# %% [markdown]
# ---
# # Network architecture

# %%
def network(x_dim, scope, factor):
    with tf.variable_scope(scope):
        net = Sequential([
            Zip([
                Linear(x_dim, 10, scope='embed_1', factor=1.0 / 3),
                Linear(x_dim, 10, scope='embed_2', factor=factor * 1.0 / 3),
                Linear(2, 10, scope='embed_3', factor=1.0 / 3),
                lambda _: 0.,
            ]),
            sum,
            tf.nn.relu,
            Linear(10, 10, scope='linear_1'),
            tf.nn.relu,
            Parallel([
                Sequential([
                    Linear(10, x_dim, scope='linear_s', factor=0.001), 
                    ScaleTanh(x_dim, scope='scale_s')
                ]),
                Linear(10, x_dim, scope='linear_t', factor=0.001),
                Sequential([
                    Linear(10, x_dim, scope='linear_f', factor=0.001),
                    ScaleTanh(x_dim, scope='scale_f'),
                ])
            ])  
        ])
        
    return net

# %% [markdown]
# ---
# # Rough Well (RW)
#
# ## Defining the distribution

# %%
x_dim = 2
eta = 1e-2
mu, cov = np.array([[0, 0]]), np.array([np.eye(2)])
dist = RoughWell(x_dim, eta, easy=True)

# %%
S = dist.get_samples(500)
fig = plt.figure()
plt.title('Rough Well ($\eta = 0.01$)')
# plot_gaussian_contours(mu, cov, colors=[c_contour], x_lims=[-3,3], y_lims=[-2,2])
plt.plot(S[:, 0], S[:, 1], 'o', alpha=0.6, color=c_true)
plt.tight_layout()
plt.axis('equal')
plt.show()
fig.savefig('rw_exact.png', dpi=200)

# %% [markdown]
# ---
# ## Training

# %%
# Leap frog integrator for Hamiltonian dynamics
dynamics = Dynamics(x_dim, dist.get_energy_function(), T=10, eps=0.1, net_factory=network)

# Losses on p(xi) and q(xi), respectively
x = tf.placeholder(tf.float32, shape=(None, x_dim))
z = tf.random_normal(tf.shape(x))
Lx, _, px, output = propose(x, dynamics, do_mh_step=True)
Lz, _, pz, _ = propose(z, dynamics, do_mh_step=False)

# Squared jumped distance
v1 = (tf.reduce_sum(tf.square(x - Lx), axis=1) * px) + 1e-4
v2 = (tf.reduce_sum(tf.square(z - Lz), axis=1) * pz) + 1e-4
scale = 0.1

# Update loss
loss = 0.
loss += scale * (tf.reduce_mean(1.0 / v1) + tf.reduce_mean(1.0 / v2))
loss += (- tf.reduce_mean(v1) - tf.reduce_mean(v2)) / scale

# %%
# Training parameters
global_step = tf.Variable(0., name='global_step', trainable=False)
learning_rate = tf.train.exponential_decay(1e-3, global_step, 1000, 0.96, staircase=True)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss, global_step=global_step)

# %%
n_steps = 5000
n_samples = 200

samples = np.random.randn(n_samples, x_dim)

sess = tf.Session(config=tf.ConfigProto(device_count = {'GPU': 0}))
sess.run(tf.global_variables_initializer())

for t in range(n_steps):
    _, loss_, samples, px_, lr_ = sess.run([
        train_op,
        loss,
        output[0],
        px,
        learning_rate,
    ], {x: samples})

    if t % 100 == 0:
        print('Step: %d / %d, Loss: %.2e, Acceptance sample: %.2f, LR: %.5f' % (t, n_steps, loss_, np.mean(px_), lr_))
# Out:
# Step: 0 / 5000, Loss: -2.83e+01, Acceptance sample: 0.90, LR: 0.00100
# Step: 100 / 5000, Loss: -3.36e+01, Acceptance sample: 0.87, LR: 0.00100
# Step: 200 / 5000, Loss: -3.71e+01, Acceptance sample: 0.80, LR: 0.00100
# Step: 300 / 5000, Loss: -3.80e+01, Acceptance sample: 0.80, LR: 0.00100
# Step: 400 / 5000, Loss: -3.79e+01, Acceptance sample: 0.74, LR: 0.00100
# Step: 500 / 5000, Loss: -3.66e+01, Acceptance sample: 0.70, LR: 0.00100
# Step: 600 / 5000, Loss: -3.41e+01, Acceptance sample: 0.72, LR: 0.00100
# Step: 700 / 5000, Loss: -3.79e+01, Acceptance sample: 0.73, LR: 0.00100
# Step: 800 / 5000, Loss: -3.03e+01, Acceptance sample: 0.73, LR: 0.00100
# Step: 900 / 5000, Loss: -3.27e+01, Acceptance sample: 0.70, LR: 0.00100
# Step: 1000 / 5000, Loss: -4.05e+01, Acceptance sample: 0.72, LR: 0.00096
# Step: 1100 / 5000, Loss: -3.92e+01, Acceptance sample: 0.73, LR: 0.00096
# Step: 1200 / 5000, Loss: -3.65e+01, Acceptance sample: 0.76, LR: 0.00096
# Step: 1300 / 5000, Loss: -3.56e+01, Acceptance sample: 0.77, LR: 0.00096
# Step: 1400 / 5000, Loss: -3.72e+01, Acceptance sample: 0.71, LR: 0.00096
# Step: 1500 / 5000, Loss: -3.79e+01, Acceptance sample: 0.78, LR: 0.00096
# Step: 1600 / 5000, Loss: -3.18e+01, Acceptance sample: 0.75, LR: 0.00096
# Step: 1700 / 5000, Loss: -3.77e+01, Acceptance sample: 0.76, LR: 0.00096
# Step: 1800 / 5000, Loss: -3.74e+01, Acceptance sample: 0.75, LR: 0.00096
# Step: 1900 / 5000, Loss: -4.86e+01, Acceptance sample: 0.78, LR: 0.00096
# Step: 2000 / 5000, Loss: -4.25e+01, Acceptance sample: 0.77, LR: 0.00092
# Step: 2100 / 5000, Loss: -4.31e+01, Acceptance sample: 0.81, LR: 0.00092
# Step: 2200 / 5000, Loss: -4.09e+01, Acceptance sample: 0.74, LR: 0.00092
# Step: 2300 / 5000, Loss: -4.20e+01, Acceptance sample: 0.72, LR: 0.00092
# Step: 2400 / 5000, Loss: -4.38e+01, Acceptance sample: 0.72, LR: 0.00092
# Step: 2500 / 5000, Loss: -4.27e+01, Acceptance sample: 0.73, LR: 0.00092
# Step: 2600 / 5000, Loss: -4.28e+01, Acceptance sample: 0.76, LR: 0.00092
# Step: 2700 / 5000, Loss: -5.04e+01, Acceptance sample: 0.75, LR: 0.00092
# Step: 2800 / 5000, Loss: -4.22e+01, Acceptance sample: 0.73, LR: 0.00092
# Step: 2900 / 5000, Loss: -4.30e+01, Acceptance sample: 0.71, LR: 0.00092
# Step: 3000 / 5000, Loss: -4.17e+01, Acceptance sample: 0.68, LR: 0.00088
# Step: 3100 / 5000, Loss: -4.59e+01, Acceptance sample: 0.69, LR: 0.00088
# Step: 3200 / 5000, Loss: -4.63e+01, Acceptance sample: 0.67, LR: 0.00088
# Step: 3300 / 5000, Loss: -4.68e+01, Acceptance sample: 0.68, LR: 0.00088
# Step: 3400 / 5000, Loss: -5.15e+01, Acceptance sample: 0.71, LR: 0.00088
# Step: 3500 / 5000, Loss: -4.51e+01, Acceptance sample: 0.73, LR: 0.00088
# Step: 3600 / 5000, Loss: -4.16e+01, Acceptance sample: 0.72, LR: 0.00088
# Step: 3700 / 5000, Loss: -4.94e+01, Acceptance sample: 0.73, LR: 0.00088
# Step: 3800 / 5000, Loss: -4.47e+01, Acceptance sample: 0.77, LR: 0.00088
# Step: 3900 / 5000, Loss: -4.23e+01, Acceptance sample: 0.75, LR: 0.00088
# Step: 4000 / 5000, Loss: -3.73e+01, Acceptance sample: 0.74, LR: 0.00085
# Step: 4100 / 5000, Loss: -4.21e+01, Acceptance sample: 0.75, LR: 0.00085
# Step: 4200 / 5000, Loss: -4.30e+01, Acceptance sample: 0.74, LR: 0.00085
# Step: 4300 / 5000, Loss: -4.42e+01, Acceptance sample: 0.76, LR: 0.00085
# Step: 4400 / 5000, Loss: -4.50e+01, Acceptance sample: 0.73, LR: 0.00085
# Step: 4500 / 5000, Loss: -3.72e+01, Acceptance sample: 0.72, LR: 0.00085
# Step: 4600 / 5000, Loss: -1.32e+01, Acceptance sample: 0.67, LR: 0.00085
# Step: 4700 / 5000, Loss: -1.54e+01, Acceptance sample: 0.67, LR: 0.00085
# Step: 4800 / 5000, Loss: -4.05e+01, Acceptance sample: 0.74, LR: 0.00085
# Step: 4900 / 5000, Loss: -4.24e+01, Acceptance sample: 0.72, LR: 0.00085

# %% [markdown]
# ---
# ## Evaluating

# %%
samples = dist.get_samples(n=n_samples)
final_samples = []

for t in range(2000):
    final_samples.append(np.copy(samples))

    feed_dict = {
        x: samples,
    }

    samples = sess.run(output[0], feed_dict)

# %%
L2HMC_samples = np.array(final_samples)
HMC_samples_1 = get_hmc_samples(2, 0.6, dist.get_energy_function(), sess, steps=2000, samples=samples)
HMC_samples_2 = get_hmc_samples(2, 0.8, dist.get_energy_function(), sess, steps=2000, samples=samples)
HMC_samples_3 = get_hmc_samples(2, 1.0, dist.get_energy_function(), sess, steps=2000, samples=samples)

# %%
#scale = np.sqrt(np.trace(cov))
scale = 1.
L2HMC = acl_spectrum(L2HMC_samples, scale=scale)
HMC1 = acl_spectrum(HMC_samples_1, scale=scale)
HMC2 = acl_spectrum(HMC_samples_2, scale=scale)
HMC3 = acl_spectrum(HMC_samples_3, scale=scale)

# %% [markdown]
# ---
# ## Auto-correlation plot

# %%
xaxis = 10 * np.arange(20)
fig = plt.figure()
plt.plot(xaxis, L2HMC[:20], label='L2HMC', color=c_l2hmc)
plt.plot(xaxis, HMC1[:20], label='HMC $\epsilon=0.6$', color=c_hmc1)
plt.plot(xaxis, HMC2[:20], label='HMC $\epsilon=0.8$', color=c_hmc2)
plt.plot(xaxis, HMC3[:20], label='HMC $\epsilon=1.0$', color=c_hmc3)
plt.ylabel('Auto-correlation')
plt.xlabel('Gradient computations')
plt.legend()
plt.title('Rough Well')
plt.tight_layout()
plt.show()
fig.savefig('rw_plot.png', dpi=200)

# %%
print('ESS L2HMC: %.2e -- ESS HMC: %.2e -- Ratio: %.3f' % (ESS(L2HMC), ESS(HMC1), ESS(L2HMC) / ESS(HMC1)))
# Out:
# ESS L2HMC: 1.92e-01 -- ESS HMC: 4.16e-02 -- Ratio: 4.609

# %% [markdown]
# ### L2HMC samples overlayed on ground truth samples

# %%
fig = plt.figure()
plot_gaussian_contours(mu, cov, colors=[c_contour], x_lims=[-2,2], y_lims=[-2,2])
plt.plot(L2HMC_samples[:50, 1, 0], L2HMC_samples[:50, 1, 1], color=c_l2hmc, marker='o', alpha=0.6)
plt.title('Rough Well Sampling via L2HMC')
plt.axis('equal')
plt.tight_layout()
plt.show()
fig.savefig('rw_explore.png', dpi=200)

# %% [markdown]
# ### HMC samples (Leapfrog step: ε = 0.6)

# %%
plot_gaussian_contours(mu, cov, colors=[c_contour], x_lims=[-3,3], y_lims=[-2,2])
plt.plot(HMC_samples_1[:50, 1, 0], HMC_samples_1[:50, 1, 1], color=c_hmc1, marker='o', alpha=0.6)
plt.title('Rough Well Sampling via HMC ($\epsilon = 0.6$)')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### HMC samples (Leapfrog step: ε = 0.8)

# %%
plot_gaussian_contours(mu, cov, colors=[c_contour], x_lims=[-3,3], y_lims=[-2,2])
plt.plot(HMC_samples_2[:50, 1, 0], HMC_samples_2[:50, 1, 1], color=c_hmc2, marker='o', alpha=0.6)
plt.title('Rough Well Sampling via HMC ($\epsilon = 0.8$)')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### HMC samples (Leapfrog step: ε = 1.0)

# %%
plot_gaussian_contours(mu, cov, colors=[c_contour], x_lims=[-3,3], y_lims=[-2,2])
plt.plot(HMC_samples_3[:50, 1, 0], HMC_samples_3[:50, 1, 1], color=c_hmc3, marker='o', alpha=0.6)
plt.title('Rough Well Sampling via HMC ($\epsilon = 1.0$)')
plt.axis('equal')
plt.show()
