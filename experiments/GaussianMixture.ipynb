# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

import sys  
sys.path.append("../l2hmc")
sys.path.append("../l2hmc/utils")

import tensorflow as tf
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from utils.distributions import random_tilted_gaussian, Gaussian, GMM, RoughWell

import seaborn as sns
sns.set_palette("muted")

# %%
from utils.func_utils import accept, jacobian, autocovariance, get_log_likelihood, \
    get_data, binarize, normal_kl, acl_spectrum, ESS
from utils.distributions import Gaussian, GMM, GaussianFunnel, gen_ring
from utils.layers import Linear, Sequential, Zip, Parallel, ScaleTanh
from utils.dynamics import Dynamics
from utils.sampler import propose
from utils.notebook_utils import get_hmc_samples, plot_gaussian_contours

# %%
# Color definition for plots
c_l2hmc, c_hmc1, c_hmc2, c_hmc3 = 'blue', 'orange', 'green', 'red'
c_true, c_contour = 'purple', '0.75'

# %% [markdown]
# ---
# # Network architecture

# %%
def network(x_dim, scope, factor):
    with tf.variable_scope(scope):
        net = Sequential([
            Zip([
                Linear(x_dim, 10, scope='embed_1', factor=1.0 / 3),
                Linear(x_dim, 10, scope='embed_2', factor=factor * 1.0 / 3),
                Linear(2, 10, scope='embed_3', factor=1.0 / 3),
                lambda _: 0.,
            ]),
            sum,
            tf.nn.relu,
            Linear(10, 10, scope='linear_1'),
            tf.nn.relu,
            Parallel([
                Sequential([
                    Linear(10, x_dim, scope='linear_s', factor=0.001), 
                    ScaleTanh(x_dim, scope='scale_s')
                ]),
                Linear(10, x_dim, scope='linear_t', factor=0.001),
                Sequential([
                    Linear(10, x_dim, scope='linear_f', factor=0.001),
                    ScaleTanh(x_dim, scope='scale_f'),
                ])
            ])  
        ])
        
    return net

# %% [markdown]
# ---
# # Mixture of Gaussians (MoG)
#
# ## Defining the distribution
#
# We define our energy function. It is a Gaussian distribution with zero mean. The covariance is a $\pi/4$ rotation of the eigenvalues $[100, 10^{-1}]$. We set up our dynamics which take as input our energy function, the number of time step of our operator, the (learnable) step-size and our architecture.

# %%
x_dim = 2
mu_1 = np.array([-2., 0.])
mu_2 = np.array([2., 0.])
mus = np.array([mu_1, mu_2])
cov_1 = 0.1 * np.eye(2)
cov_2 = 0.1 * np.eye(2)
covs = np.array([cov_1, cov_2])
pis = np.array([0.5, 0.5])
dist = GMM(mus, covs, pis)

# %%
S = dist.get_samples(100)
main, secondary = '#6706F1', '#F106B2'
plt.title('Isotropic Mixture of Gaussians (MoG)')
plot_gaussian_contours(mus, covs, colors=[c_contour, c_contour], x_lims=[-3,3], y_lims=[-2,2])
plt.plot(S[:, 0], S[:, 1], 'o', alpha=0.6, color=c_true)
plt.axis('equal')
plt.show()

# %% [markdown]
# ---
# ## Training

# %%
# Leap frog integrator for Hamiltonian dynamics
# temperature = tf.placeholder(tf.float32, shape=())
dynamics = Dynamics(x_dim, dist.get_energy_function(), T=10, eps=0.1, net_factory=network, 
                    use_temperature=True)#, temperature=temperature)
 #               use_temperature=True, init_temperature=5.0, annealing_range=5000)

# Losses on p(xi) and q(xi), respectively
x = tf.placeholder(tf.float32, shape=(None, x_dim))
z = tf.random_normal(tf.shape(x))
Lx, _, px, output = propose(x, dynamics, do_mh_step=True)
Lz, _, pz, _ = propose(z, dynamics, do_mh_step=False)

# Squared jumped distance
v1 = (tf.reduce_sum(tf.square(x - Lx), axis=1) * px) + 1e-4
v2 = (tf.reduce_sum(tf.square(z - Lz), axis=1) * pz) + 1e-4
scale = 0.1

# Update loss
loss = 0.
loss += scale * (tf.reduce_mean(1.0 / v1) + tf.reduce_mean(1.0 / v2))
loss += (- tf.reduce_mean(v1) - tf.reduce_mean(v2)) / scale

# %%
# Training parameters
global_step = tf.Variable(0., name='global_step', trainable=False)
learning_rate = tf.train.exponential_decay(1e-3, global_step, 1000, 0.96, staircase=True)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss, global_step=global_step)

# %%
n_steps = 5000
n_samples = 200

samples = np.random.randn(n_samples, x_dim)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for t in range(n_steps):
    tmp = 24.0*(1 - t/float(n_steps)) + 1
    _, loss_, samples, px_, lr_ = sess.run([
        train_op,
        loss,
        output[0],
        px,
        learning_rate
    ], {x: samples, dynamics.temperature: tmp})

    if t % 100 == 0:
        print('Step: %d / %d, Loss: %.2e, Acceptance sample: %.2f, LR: %.5f, Temp: %.4f' % (t, n_steps, loss_, np.mean(px_), lr_, tmp))
# Out:
# Step: 0 / 5000, Loss: -3.58e+01, Acceptance sample: 0.97, LR: 0.00100, Temp: 25.0000
# Step: 100 / 5000, Loss: -7.97e+01, Acceptance sample: 0.89, LR: 0.00100, Temp: 24.5200
# Step: 200 / 5000, Loss: -1.65e+02, Acceptance sample: 0.69, LR: 0.00100, Temp: 24.0400
# Step: 300 / 5000, Loss: -2.38e+02, Acceptance sample: 0.71, LR: 0.00100, Temp: 23.5600
# Step: 400 / 5000, Loss: -3.52e+02, Acceptance sample: 0.84, LR: 0.00100, Temp: 23.0800
# Step: 500 / 5000, Loss: -3.90e+02, Acceptance sample: 0.88, LR: 0.00100, Temp: 22.6000
# Step: 600 / 5000, Loss: -3.91e+02, Acceptance sample: 0.89, LR: 0.00100, Temp: 22.1200
# Step: 700 / 5000, Loss: -4.24e+02, Acceptance sample: 0.93, LR: 0.00100, Temp: 21.6400
# Step: 800 / 5000, Loss: -3.91e+02, Acceptance sample: 0.92, LR: 0.00100, Temp: 21.1600
# Step: 900 / 5000, Loss: -4.00e+02, Acceptance sample: 0.93, LR: 0.00100, Temp: 20.6800
# Step: 1000 / 5000, Loss: -4.08e+02, Acceptance sample: 0.95, LR: 0.00096, Temp: 20.2000
# Step: 1100 / 5000, Loss: -3.93e+02, Acceptance sample: 0.96, LR: 0.00096, Temp: 19.7200
# Step: 1200 / 5000, Loss: -4.19e+02, Acceptance sample: 0.95, LR: 0.00096, Temp: 19.2400
# Step: 1300 / 5000, Loss: -3.90e+02, Acceptance sample: 0.96, LR: 0.00096, Temp: 18.7600
# Step: 1400 / 5000, Loss: -4.15e+02, Acceptance sample: 0.95, LR: 0.00096, Temp: 18.2800
# Step: 1500 / 5000, Loss: -3.62e+02, Acceptance sample: 0.96, LR: 0.00096, Temp: 17.8000
# Step: 1600 / 5000, Loss: -3.87e+02, Acceptance sample: 0.96, LR: 0.00096, Temp: 17.3200
# Step: 1700 / 5000, Loss: -4.05e+02, Acceptance sample: 0.96, LR: 0.00096, Temp: 16.8400
# Step: 1800 / 5000, Loss: -3.70e+02, Acceptance sample: 0.96, LR: 0.00096, Temp: 16.3600
# Step: 1900 / 5000, Loss: -3.35e+02, Acceptance sample: 0.97, LR: 0.00096, Temp: 15.8800
# Step: 2000 / 5000, Loss: -3.31e+02, Acceptance sample: 0.96, LR: 0.00092, Temp: 15.4000
# Step: 2100 / 5000, Loss: -3.49e+02, Acceptance sample: 0.97, LR: 0.00092, Temp: 14.9200
# Step: 2200 / 5000, Loss: -3.45e+02, Acceptance sample: 0.97, LR: 0.00092, Temp: 14.4400
# Step: 2300 / 5000, Loss: -3.34e+02, Acceptance sample: 0.98, LR: 0.00092, Temp: 13.9600
# Step: 2400 / 5000, Loss: -3.43e+02, Acceptance sample: 0.98, LR: 0.00092, Temp: 13.4800
# Step: 2500 / 5000, Loss: -3.35e+02, Acceptance sample: 0.97, LR: 0.00092, Temp: 13.0000
# Step: 2600 / 5000, Loss: -3.44e+02, Acceptance sample: 0.97, LR: 0.00092, Temp: 12.5200
# Step: 2700 / 5000, Loss: -3.42e+02, Acceptance sample: 0.98, LR: 0.00092, Temp: 12.0400
# Step: 2800 / 5000, Loss: -3.48e+02, Acceptance sample: 0.97, LR: 0.00092, Temp: 11.5600
# Step: 2900 / 5000, Loss: -3.31e+02, Acceptance sample: 0.97, LR: 0.00092, Temp: 11.0800
# Step: 3000 / 5000, Loss: -3.26e+02, Acceptance sample: 0.97, LR: 0.00088, Temp: 10.6000
# Step: 3100 / 5000, Loss: -3.26e+02, Acceptance sample: 0.97, LR: 0.00088, Temp: 10.1200
# Step: 3200 / 5000, Loss: -2.94e+02, Acceptance sample: 0.97, LR: 0.00088, Temp: 9.6400
# Step: 3300 / 5000, Loss: -3.05e+02, Acceptance sample: 0.98, LR: 0.00088, Temp: 9.1600
# Step: 3400 / 5000, Loss: -3.03e+02, Acceptance sample: 0.98, LR: 0.00088, Temp: 8.6800
# Step: 3500 / 5000, Loss: -3.04e+02, Acceptance sample: 0.97, LR: 0.00088, Temp: 8.2000
# Step: 3600 / 5000, Loss: -3.02e+02, Acceptance sample: 0.97, LR: 0.00088, Temp: 7.7200
# Step: 3700 / 5000, Loss: -3.09e+02, Acceptance sample: 0.98, LR: 0.00088, Temp: 7.2400
# Step: 3800 / 5000, Loss: -3.21e+02, Acceptance sample: 0.98, LR: 0.00088, Temp: 6.7600
# Step: 3900 / 5000, Loss: -3.04e+02, Acceptance sample: 0.97, LR: 0.00088, Temp: 6.2800
# Step: 4000 / 5000, Loss: -2.84e+02, Acceptance sample: 0.98, LR: 0.00085, Temp: 5.8000
# Step: 4100 / 5000, Loss: -2.72e+02, Acceptance sample: 0.98, LR: 0.00085, Temp: 5.3200
# Step: 4200 / 5000, Loss: -2.81e+02, Acceptance sample: 0.96, LR: 0.00085, Temp: 4.8400
# Step: 4300 / 5000, Loss: -2.94e+02, Acceptance sample: 0.97, LR: 0.00085, Temp: 4.3600
# Step: 4400 / 5000, Loss: -2.77e+02, Acceptance sample: 0.97, LR: 0.00085, Temp: 3.8800
# Step: 4500 / 5000, Loss: -2.58e+02, Acceptance sample: 0.93, LR: 0.00085, Temp: 3.4000
# Step: 4600 / 5000, Loss: -2.48e+02, Acceptance sample: 0.92, LR: 0.00085, Temp: 2.9200
# Step: 4700 / 5000, Loss: -2.43e+02, Acceptance sample: 0.94, LR: 0.00085, Temp: 2.4400
# Step: 4800 / 5000, Loss: -2.10e+02, Acceptance sample: 0.90, LR: 0.00085, Temp: 1.9600
# Step: 4900 / 5000, Loss: -2.11e+02, Acceptance sample: 0.91, LR: 0.00085, Temp: 1.4800

# %% [markdown]
# ---
# ## Evaluating

# %%
samples = dist.get_samples(n=n_samples)
final_samples = []

for t in range(2000):
    final_samples.append(np.copy(samples))

    feed_dict = {
        x: samples,
        dynamics.temperature: 1.0
    }

    samples = sess.run(output[0], feed_dict)

# %% [markdown]
# We compute the HMC chains with **auto-correlation spectrums** as well.

# %%
L2HMC_samples = np.array(final_samples)
HMC_samples_1 = get_hmc_samples(2, 0.25, dist.get_energy_function(), sess, steps=2000, samples=samples)
HMC_samples_2 = get_hmc_samples(2, 0.5, dist.get_energy_function(), sess, steps=2000, samples=samples)

# %%
scale = 2.1#np.sqrt(np.trace(covs))
L2HMC = acl_spectrum(L2HMC_samples, scale=scale)
HMC1 = acl_spectrum(HMC_samples_1, scale=scale)
HMC2 = acl_spectrum(HMC_samples_2, scale=scale)

# %% [markdown]
# ---
# ## Auto-correlation plot

# %%
xaxis = 10 * np.arange(50)
plt.plot(xaxis, L2HMC[:50], label='L2HMC', color=c_l2hmc)
plt.plot(xaxis, HMC1[:50], label='HMC $\epsilon=0.6$', color=c_hmc1)
plt.plot(xaxis, HMC2[:50], label='HMC $\epsilon=0.8$', color=c_hmc2)
# plt.plot(xaxis, HMC3[:500], label='HMC $\epsilon=1.0$', color=c_hmc3)
plt.ylabel('Auto-correlation')
plt.xlabel('Gradient Computations')
plt.legend()
plt.show()

# %% [markdown]
# We now compute the **Effective Sample Size** (ESS).

# %%
print('ESS L2HMC: %.2e -- ESS HMC: %.2e -- Ratio: %.3f' % (ESS(L2HMC), ESS(HMC1), ESS(L2HMC) / ESS(HMC1)))
# Out:
# ESS L2HMC: 5.62e-01 -- ESS HMC: 2.76e-04 -- Ratio: 2039.087

# %% [markdown]
# Finally, we visualize a single chain of L2HMC for 50 time steps to assess exploration.

# %% [markdown]
# ### L2HMC samples overlayed on ground truth samples

# %%
# plt.plot(S[:, 0], S[:, 1], 'o', alpha=0.6, color=main)
plot_gaussian_contours(mus, covs, colors=[c_contour, c_contour], x_lims=[-3,3], y_lims=[-2,2])
plt.plot(L2HMC_samples[:50, 1, 0], L2HMC_samples[:50, 1, 1], color=c_l2hmc, marker='o', alpha=0.6)
plt.title('MoG Sampling Using L2HMC')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### HMC samples (Leapfrog step: ε = 0.25)

# %%
plot_gaussian_contours(mus, covs, colors=[c_contour], x_lims=[-3,3], y_lims=[-2,2])
plt.plot(HMC_samples_1[:50, 1, 0], HMC_samples_1[:50, 1, 1], color=c_hmc1, marker='o', alpha=0.6)
plt.title('MoG Sampling Using HMC ($\epsilon = 0.25$)')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### HMC samples (Leapfrog step: ε = 0.50)

# %%
plot_gaussian_contours(mus, covs, colors=[c_contour], x_lims=[-3,3], y_lims=[-2,2])
plt.plot(HMC_samples_2[:50, 1, 0], HMC_samples_2[:50, 1, 1], color=c_hmc2, marker='o', alpha=0.6)
plt.title('MoG Sampling Using HMC ($\epsilon = 0.5$)')
plt.axis('equal')
plt.show()
